# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_features = pd.read_parquet('train_features.parquet')
test_features = pd.read_parquet('test_features.parquet')

# %%
# selected rows with na values
train_features[train_features.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [img_red_mean_date1, img_green_mean_date1, img_blue_mean_date1, img_red_std_date1, img_green_std_date1, img_blue_std_date1, img_red_mean_date2, img_green_mean_date2, img_blue_mean_date2, img_red_std_date2, img_green_std_date2, img_blue_std_date2, img_red_mean_date3, img_green_mean_date3, img_blue_mean_date3, img_red_std_date3, img_green_std_date3, img_blue_std_date3, img_red_mean_date4, img_green_mean_date4, img_blue_mean_date4, img_red_std_date4, img_green_std_date4, img_blue_std_date4, img_red_mean_date5, img_green_mean_date5, img_blue_mean_date5, img_red_std_date5, img_green_std_date5, img_blue_std_date5, urban_Dense Urban, urban_Industrial, urban_Rural, urban_Sparse Urban, urban_Urban Slum, change_status_date1, change_status_date2, change_status_date3, change_status_date4, geo_Barren Land, geo_Coastal, geo_Dense Forest, geo_Desert, geo_Farms, geo_Grass Land, geo_Hills, geo_Lakes, geo_River, geo_Snow, geo_Sparse Forest, interval_1_2, interval_2_3, interval_3_4, area, perimeter, x_centroid, y_centroid]
# Index: []
#
# [0 rows x 57 columns]
